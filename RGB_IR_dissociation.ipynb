# %%
# Importing Image class from PIL module
# %matplotlib inline
from PIL import Image
# Out:
# /home/dario/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#image_path='/home/dario/KonzaBurn/images/sage_mobotix_cam_20220414-001125_6144x2048.jpg'
image_path='/home/dario/KonzaBurn/selected_images/Konza_20220415-182058cb1-crop.jpg'

# %%
# Opens a image in RGB mode
im = Image.open(image_path)
#im.show()
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1696x758 at 0x76B34C447550>

# %%
# Size of the image in pixels (size of original image)
# (This is not mandatory)
width, height = im.size

# %%
# Setting the points for cropped image
left = 0
top = 0
#top = height / 4
right = width / 2
bottom = height
#bottom = 3 * height / 4

# %%
# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))

# %%
display(im1)
# Out:
# <PIL.Image.Image image mode=RGB size=848x758 at 0x76B34C446A10>

# %%
# Setting the points for cropped image
left = width / 2
top = 0
#top = height / 4
right = width
bottom = height
#bottom = 3 * height / 4

# %%
# Cropped image of above dimension
# (It will not change original image)
im2 = im.crop((left, top, right, bottom))

# %%
display(im2)
# Out:
# <PIL.Image.Image image mode=RGB size=848x758 at 0x76B2FAADA890>
